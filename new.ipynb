# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

from sklearn.model_selection import  cross_validate, learning_curve, GridSearchCV, TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv('index.csv')
df.insert(0, "Date", pd.to_datetime(df[["Year", "Month", "Day"]]))      # create datetime column
df.set_index(["Date"], inplace=True)                                    # set index to date, easy to handle 
df.drop(columns=["Year", "Month", "Day"], inplace=True)                 # deop redundant columns

df.drop(columns=["Federal Funds Target Rate", "Federal Funds Upper Target", "Federal Funds Lower Target"], inplace=True)        # these columns will not be used

targ_df = pd.DataFrame(df["Real GDP (Percent Change)"])     # create target and drop the NaNs to get to quarterly values
targ_df.head(5)
# Out:
#             Real GDP (Percent Change)
# Date
# 1954-07-01                        4.6
# 1954-08-01                        NaN
# 1954-09-01                        NaN
# 1954-10-01                        8.0
# 1954-11-01                        NaN

# %%
# determine date when inflation rate begins to ve recorded 
for i,j in enumerate(df["Inflation Rate"]):
    if not np.isnan(j):
        print(df.iloc[i])
        break
# Out:
# Effective Federal Funds Rate     2.72
# Real GDP (Percent Change)      -10.00
# Unemployment Rate                5.80
# Inflation Rate                   3.20
# Name: 1958-01-01 00:00:00, dtype: float64

# %%
df.drop(df.loc["1954-07-01":"1958-01-01"].index, inplace=True)      # drop the rows with no inflation rate
df.drop(df.loc["2016-11-01":].index, inplace=True) # drop as there is no target for these dates

targ_df.drop(targ_df.loc["1954-07-01":"1958-01-01"].index, inplace=True)      # drop the rows with no inflation rate
targ_df.drop(targ_df.loc["2016-11-01":].index, inplace=True) # drop as there is no target for these dates

# %%
# remove mid-month entries as these were wgen target rates were chanmged, theses only contain NaNs for our feqture vaeriables 
idx_mm = [i for i,j in enumerate(df.index.day) if j != 1]
df.drop(df.iloc[idx_mm].index, inplace=True) 
# same for targ df
idx_mm = [i for i,j in enumerate(targ_df.index.day) if j != 1]
targ_df.drop(targ_df.iloc[idx_mm].index, inplace=True)

# %%
tss = TimeSeriesSplit(n_splits = 2)         # use time series train test split so we do not train on future data, 2 splits to increse cv sample size

for train_index, test_index in tss.split(df, targ_df):
    X_train, X_test = df.iloc[train_index, :].copy(), df.iloc[test_index,:].copy()
    y_train, y_test = targ_df.iloc[train_index].copy(), targ_df.iloc[test_index].copy()

# %%
X_train["Real GDP (Percent Change)"] = df["Real GDP (Percent Change)"].interpolate()       # interpolate the target so we can create quarterly lags
X_test["Real GDP (Percent Change)"] = df["Real GDP (Percent Change)"].interpolate()       # interpolate the target so we can create quarterly lags
X_train.head(3)
# Out:
#             Effective Federal Funds Rate  Real GDP (Percent Change)  \
# Date
# 1958-02-01                          1.67                        NaN
# 1958-03-01                          1.20                        NaN
# 1958-04-01                          1.26                        2.6
#
#             Unemployment Rate  Inflation Rate
# Date
# 1958-02-01                6.4             3.2
# 1958-03-01                6.7             2.8
# 1958-04-01                7.4             2.4

# %%
# remove nans from lags 
y_train = y_train.loc["1958-02-01":"1997-03-25"].dropna()
y_test = y_test.loc["1997-03-25":"1997-03-25"].dropna()

# %%
lags = [1,2,3,4,5]        # introduce lag features 
cols = ["Effective Federal Funds Rate", "Inflation Rate", "Unemployment Rate", "Real GDP (Percent Change)"]  # include target to create its own lags 

# loop and dynamically name lags
for col in cols:
    for L in lags:
        X_train[f"{col} lag{L}"] = X_train[col].shift(L)
X_train.tail(5)
# Out:
#             Effective Federal Funds Rate  Real GDP (Percent Change)  \
# Date
# 1996-11-01                          5.31                   3.900000
# 1996-12-01                          5.29                   3.500000
# 1997-01-01                          5.25                   3.100000
# 1997-02-01                          5.19                   4.133333
# 1997-03-01                          5.39                   5.166667
#
#             Unemployment Rate  Inflation Rate  \
# Date
# 1996-11-01                5.4             2.6
# 1996-12-01                5.4             2.6
# 1997-01-01                5.3             2.5
# 1997-02-01                5.2             2.5
# 1997-03-01                5.2             2.5
#
#             Effective Federal Funds Rate lag1  \
# Date
# 1996-11-01                               5.24
# 1996-12-01                               5.31
# 1997-01-01                               5.29
# 1997-02-01                               5.25
# 1997-03-01                               5.19
#
#             Effective Federal Funds Rate lag2  \
# Date
# 1996-11-01                               5.30
# 1996-12-01                               5.24
# 1997-01-01                               5.31
# 1997-02-01                               5.29
# 1997-03-01                               5.25
#
#             Effective Federal Funds Rate lag3  \
# Date
# 1996-11-01                               5.22
# 1996-12-01                               5.30
# 1997-01-01                               5.24
# 1997-02-01                               5.31
# 1997-03-01                               5.29
#
#             Effective Federal Funds Rate lag4  \
# Date
# 1996-11-01                               5.40
# 1996-12-01                               5.22
# 1997-01-01                               5.30
# 1997-02-01                               5.24
# 1997-03-01                               5.31
#
#             Effective Federal Funds Rate lag5  Inflation Rate lag1  ...  \
# Date                                                                ...
# 1996-11-01                               5.27                  2.6  ...
# 1996-12-01                               5.40                  2.6  ...
# 1997-01-01                               5.22                  2.6  ...
# 1997-02-01                               5.30                  2.5  ...
# 1997-03-01                               5.24                  2.5  ...
#
#             Unemployment Rate lag1  Unemployment Rate lag2  \
# Date
# 1996-11-01                     5.2                     5.2
# 1996-12-01                     5.4                     5.2
# 1997-01-01                     5.4                     5.4
# 1997-02-01                     5.3                     5.4
# 1997-03-01                     5.2                     5.3
#
#             Unemployment Rate lag3  Unemployment Rate lag4  \
# Date
# 1996-11-01                     5.1                     5.5
# 1996-12-01                     5.2                     5.1
# 1997-01-01                     5.2                     5.2
# 1997-02-01                     5.4                     5.2
# 1997-03-01                     5.4                     5.4
#
#             Unemployment Rate lag5  Real GDP (Percent Change) lag1  \
# Date
# 1996-11-01                     5.3                        4.300000
# 1996-12-01                     5.5                        3.900000
# 1997-01-01                     5.1                        3.500000
# 1997-02-01                     5.2                        3.100000
# 1997-03-01                     5.2                        4.133333
#
#             Real GDP (Percent Change) lag2  Real GDP (Percent Change) lag3  \
# Date
# 1996-11-01                             4.1                             3.9
# 1996-12-01                             4.3                             4.1
# 1997-01-01                             3.9                             4.3
# 1997-02-01                             3.5                             3.9
# 1997-03-01                             3.1                             3.5
#
#             Real GDP (Percent Change) lag4  Real GDP (Percent Change) lag5
# Date
# 1996-11-01                             3.7                        4.866667
# 1996-12-01                             3.9                        3.700000
# 1997-01-01                             4.1                        3.900000
# 1997-02-01                             4.3                        4.100000
# 1997-03-01                             3.9                        4.300000
#
# [5 rows x 24 columns]

# %%
lags = [1,2,3,4,5]        # introduce lag features 
cols = ["Effective Federal Funds Rate", "Inflation Rate", "Unemployment Rate", "Real GDP (Percent Change)"]  # include target to create its own lags 

# loop and dynamically name lags
for col in cols:
    for L in lags:
        X_test[f"{col} lag{L}"] = X_test[col].shift(L)
X_test.head(5)
# Out:
#             Effective Federal Funds Rate  Real GDP (Percent Change)  \
# Date
# 1997-04-01                          5.51                   6.200000
# 1997-05-01                          5.50                   5.866667
# 1997-06-01                          5.56                   5.533333
# 1997-07-01                          5.52                   5.200000
# 1997-08-01                          5.54                   4.500000
#
#             Unemployment Rate  Inflation Rate  \
# Date
# 1997-04-01                5.1             2.7
# 1997-05-01                4.9             2.5
# 1997-06-01                5.0             2.4
# 1997-07-01                4.9             2.4
# 1997-08-01                4.8             2.3
#
#             Effective Federal Funds Rate lag1  \
# Date
# 1997-04-01                                NaN
# 1997-05-01                               5.51
# 1997-06-01                               5.50
# 1997-07-01                               5.56
# 1997-08-01                               5.52
#
#             Effective Federal Funds Rate lag2  \
# Date
# 1997-04-01                                NaN
# 1997-05-01                                NaN
# 1997-06-01                               5.51
# 1997-07-01                               5.50
# 1997-08-01                               5.56
#
#             Effective Federal Funds Rate lag3  \
# Date
# 1997-04-01                                NaN
# 1997-05-01                                NaN
# 1997-06-01                                NaN
# 1997-07-01                               5.51
# 1997-08-01                               5.50
#
#             Effective Federal Funds Rate lag4  \
# Date
# 1997-04-01                                NaN
# 1997-05-01                                NaN
# 1997-06-01                                NaN
# 1997-07-01                                NaN
# 1997-08-01                               5.51
#
#             Effective Federal Funds Rate lag5  Inflation Rate lag1  ...  \
# Date                                                                ...
# 1997-04-01                                NaN                  NaN  ...
# 1997-05-01                                NaN                  2.7  ...
# 1997-06-01                                NaN                  2.5  ...
# 1997-07-01                                NaN                  2.4  ...
# 1997-08-01                                NaN                  2.4  ...
#
#             Unemployment Rate lag1  Unemployment Rate lag2  \
# Date
# 1997-04-01                     NaN                     NaN
# 1997-05-01                     5.1                     NaN
# 1997-06-01                     4.9                     5.1
# 1997-07-01                     5.0                     4.9
# 1997-08-01                     4.9                     5.0
#
#             Unemployment Rate lag3  Unemployment Rate lag4  \
# Date
# 1997-04-01                     NaN                     NaN
# 1997-05-01                     NaN                     NaN
# 1997-06-01                     NaN                     NaN
# 1997-07-01                     5.1                     NaN
# 1997-08-01                     4.9                     5.1
#
#             Unemployment Rate lag5  Real GDP (Percent Change) lag1  \
# Date
# 1997-04-01                     NaN                             NaN
# 1997-05-01                     NaN                        6.200000
# 1997-06-01                     NaN                        5.866667
# 1997-07-01                     NaN                        5.533333
# 1997-08-01                     NaN                        5.200000
#
#             Real GDP (Percent Change) lag2  Real GDP (Percent Change) lag3  \
# Date
# 1997-04-01                             NaN                             NaN
# 1997-05-01                             NaN                             NaN
# 1997-06-01                        6.200000                             NaN
# 1997-07-01                        5.866667                        6.200000
# 1997-08-01                        5.533333                        5.866667
#
#             Real GDP (Percent Change) lag4  Real GDP (Percent Change) lag5
# Date
# 1997-04-01                             NaN                             NaN
# 1997-05-01                             NaN                             NaN
# 1997-06-01                             NaN                             NaN
# 1997-07-01                             NaN                             NaN
# 1997-08-01                             6.2                             NaN
#
# [5 rows x 24 columns]

# %%
X_train.drop(X_train.iloc[0:6].index, inplace=True)
X_test.drop(X_test.iloc[0:6].index, inplace=True)

# %%
X_train.drop(columns="Real GDP (Percent Change)", inplace=True)
X_train.head(5)
# Out:
#             Effective Federal Funds Rate  Unemployment Rate  Inflation Rate  \
# Date
# 1958-08-01                          1.53                7.4             2.1
# 1958-09-01                          1.76                7.1             1.7
# 1958-10-01                          1.80                6.7             1.7
# 1958-11-01                          2.27                6.2             1.7
# 1958-12-01                          2.42                6.2             1.7
#
#             Effective Federal Funds Rate lag1  \
# Date
# 1958-08-01                               0.68
# 1958-09-01                               1.53
# 1958-10-01                               1.76
# 1958-11-01                               1.80
# 1958-12-01                               2.27
#
#             Effective Federal Funds Rate lag2  \
# Date
# 1958-08-01                               0.93
# 1958-09-01                               0.68
# 1958-10-01                               1.53
# 1958-11-01                               1.76
# 1958-12-01                               1.80
#
#             Effective Federal Funds Rate lag3  \
# Date
# 1958-08-01                               0.63
# 1958-09-01                               0.93
# 1958-10-01                               0.68
# 1958-11-01                               1.53
# 1958-12-01                               1.76
#
#             Effective Federal Funds Rate lag4  \
# Date
# 1958-08-01                               1.26
# 1958-09-01                               0.63
# 1958-10-01                               0.93
# 1958-11-01                               0.68
# 1958-12-01                               1.53
#
#             Effective Federal Funds Rate lag5  Inflation Rate lag1  \
# Date
# 1958-08-01                               1.20                  2.4
# 1958-09-01                               1.26                  2.1
# 1958-10-01                               0.63                  1.7
# 1958-11-01                               0.93                  1.7
# 1958-12-01                               0.68                  1.7
#
#             Inflation Rate lag2  ...  Unemployment Rate lag1  \
# Date                             ...
# 1958-08-01                  2.1  ...                     7.5
# 1958-09-01                  2.4  ...                     7.4
# 1958-10-01                  2.1  ...                     7.1
# 1958-11-01                  1.7  ...                     6.7
# 1958-12-01                  1.7  ...                     6.2
#
#             Unemployment Rate lag2  Unemployment Rate lag3  \
# Date
# 1958-08-01                     7.3                     7.4
# 1958-09-01                     7.5                     7.3
# 1958-10-01                     7.4                     7.5
# 1958-11-01                     7.1                     7.4
# 1958-12-01                     6.7                     7.1
#
#             Unemployment Rate lag4  Unemployment Rate lag5  \
# Date
# 1958-08-01                     7.4                     6.7
# 1958-09-01                     7.4                     7.4
# 1958-10-01                     7.3                     7.4
# 1958-11-01                     7.5                     7.3
# 1958-12-01                     7.4                     7.5
#
#             Real GDP (Percent Change) lag1  Real GDP (Percent Change) lag2  \
# Date
# 1958-08-01                        9.600000                        7.266667
# 1958-09-01                        9.633333                        9.600000
# 1958-10-01                        9.666667                        9.633333
# 1958-11-01                        9.700000                        9.666667
# 1958-12-01                        9.033333                        9.700000
#
#             Real GDP (Percent Change) lag3  Real GDP (Percent Change) lag4  \
# Date
# 1958-08-01                        4.933333                        2.600000
# 1958-09-01                        7.266667                        4.933333
# 1958-10-01                        9.600000                        7.266667
# 1958-11-01                        9.633333                        9.600000
# 1958-12-01                        9.666667                        9.633333
#
#             Real GDP (Percent Change) lag5
# Date
# 1958-08-01                             NaN
# 1958-09-01                        2.600000
# 1958-10-01                        4.933333
# 1958-11-01                        7.266667
# 1958-12-01                        9.600000
#
# [5 rows x 23 columns]

# %%
X_test.drop(columns="Real GDP (Percent Change)", inplace=True)
X_test.head(5)
# Out:
#             Effective Federal Funds Rate  Unemployment Rate  Inflation Rate  \
# Date
# 1997-10-01                          5.50                4.7             2.3
# 1997-11-01                          5.52                4.6             2.2
# 1997-12-01                          5.50                4.7             2.2
# 1998-01-01                          5.56                4.6             2.2
# 1998-02-01                          5.51                4.6             2.3
#
#             Effective Federal Funds Rate lag1  \
# Date
# 1997-10-01                               5.54
# 1997-11-01                               5.50
# 1997-12-01                               5.52
# 1998-01-01                               5.50
# 1998-02-01                               5.56
#
#             Effective Federal Funds Rate lag2  \
# Date
# 1997-10-01                               5.54
# 1997-11-01                               5.54
# 1997-12-01                               5.50
# 1998-01-01                               5.52
# 1998-02-01                               5.50
#
#             Effective Federal Funds Rate lag3  \
# Date
# 1997-10-01                               5.52
# 1997-11-01                               5.54
# 1997-12-01                               5.54
# 1998-01-01                               5.50
# 1998-02-01                               5.52
#
#             Effective Federal Funds Rate lag4  \
# Date
# 1997-10-01                               5.56
# 1997-11-01                               5.52
# 1997-12-01                               5.54
# 1998-01-01                               5.54
# 1998-02-01                               5.50
#
#             Effective Federal Funds Rate lag5  Inflation Rate lag1  \
# Date
# 1997-10-01                               5.50                  2.2
# 1997-11-01                               5.56                  2.3
# 1997-12-01                               5.52                  2.2
# 1998-01-01                               5.54                  2.2
# 1998-02-01                               5.54                  2.2
#
#             Inflation Rate lag2  ...  Unemployment Rate lag1  \
# Date                             ...
# 1997-10-01                  2.3  ...                     4.9
# 1997-11-01                  2.2  ...                     4.7
# 1997-12-01                  2.3  ...                     4.6
# 1998-01-01                  2.2  ...                     4.7
# 1998-02-01                  2.2  ...                     4.6
#
#             Unemployment Rate lag2  Unemployment Rate lag3  \
# Date
# 1997-10-01                     4.8                     4.9
# 1997-11-01                     4.9                     4.8
# 1997-12-01                     4.7                     4.9
# 1998-01-01                     4.6                     4.7
# 1998-02-01                     4.7                     4.6
#
#             Unemployment Rate lag4  Unemployment Rate lag5  \
# Date
# 1997-10-01                     5.0                     4.9
# 1997-11-01                     4.9                     5.0
# 1997-12-01                     4.8                     4.9
# 1998-01-01                     4.9                     4.8
# 1998-02-01                     4.7                     4.9
#
#             Real GDP (Percent Change) lag1  Real GDP (Percent Change) lag2  \
# Date
# 1997-10-01                             3.8                             4.5
# 1997-11-01                             3.1                             3.8
# 1997-12-01                             3.4                             3.1
# 1998-01-01                             3.7                             3.4
# 1998-02-01                             4.0                             3.7
#
#             Real GDP (Percent Change) lag3  Real GDP (Percent Change) lag4  \
# Date
# 1997-10-01                             5.2                        5.533333
# 1997-11-01                             4.5                        5.200000
# 1997-12-01                             3.8                        4.500000
# 1998-01-01                             3.1                        3.800000
# 1998-02-01                             3.4                        3.100000
#
#             Real GDP (Percent Change) lag5
# Date
# 1997-10-01                        5.866667
# 1997-11-01                        5.533333
# 1997-12-01                        5.200000
# 1998-01-01                        4.500000
# 1998-02-01                        3.800000
#
# [5 rows x 23 columns]

# %%
print(X_train[["Unemployment Rate", "Effective Federal Funds Rate", "Inflation Rate"]].isna().sum() )       # check if all are removed
print(y_train["Real GDP (Percent Change)"].isna().sum())        # check if all are removed
print(X_test[["Unemployment Rate", "Effective Federal Funds Rate", "Inflation Rate"]].isna().sum())        # check if all are removed
print(y_test["Real GDP (Percent Change)"].isna().sum())        # check if all are removed
# Out:
# Unemployment Rate               0
# Effective Federal Funds Rate    0
# Inflation Rate                  0
# dtype: int64
# 0
# Unemployment Rate               0
# Effective Federal Funds Rate    0
# Inflation Rate                  0
# dtype: int64
# 0

# %% [markdown]
# Now need to reduce to quartely evaluation:

# %%
y_train = y_train.loc["1958-08-01":"1997-03-01"]        # limits of X_train
y_train = y_train.dropna()                              # get rid of monthly values
X_train = X_train.loc[y_train.index]                    # use index of targ to change X
sum(y_train.index != X_train.index)                     # check
# Out:
# np.int64(0)

# %%
# same for test dataset
y_test = y_test.loc["1997-10-01":"2016-10-01"]
y_test = y_test.dropna()
X_test = X_test.loc[y_test.index]
sum(y_train.index != X_train.index)
# Out:
# np.int64(0)
